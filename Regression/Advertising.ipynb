# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('advertising.csv')
print(df.head())
print(df.tail())
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
print(df.shape)
print(df.dtypes)
print(df.info)
# Out:
# (200, 4)
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object
# <bound method DataFrame.info of         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]>

# %%
df.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
plt.scatter(df['Newspaper'],df['Sales'], color='r')
plt.xlabel('Newspaper')
plt.ylabel('Sales')
plt.title('Product Sales')
# Out:
# Text(0.5, 1.0, 'Product Sales')

# %%
plt.scatter(df['Radio'],df['Sales'], color='g')
plt.xlabel('Radio')
plt.ylabel('Sales')
plt.title('Product Sales')
# Out:
# Text(0.5, 1.0, 'Product Sales')

# %%
plt.scatter(df['TV'],df['Sales'], color='b')
plt.xlabel('TV')
plt.ylabel('Sales')
plt.title('Product Sales')
# Out:
# Text(0.5, 1.0, 'Product Sales')

# %%
y=df['Sales']
sns.regplot(x=df['Newspaper'],y=y,color='r')
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
sns.regplot(x=df['Radio'],y=y,color='g')
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
sns.regplot(x=df['TV'],y=y,color='b')
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([15.6862146 , 13.26304256,  5.94415096, 24.42493494, 20.44607402,
#         7.84251715, 11.02079385, 15.80463245,  8.16392844, 11.57368809,
#         9.43705904,  8.44778501, 20.23391688, 10.49566534, 14.07849053,
#        21.67850197, 18.06747736, 16.66307165, 14.87030413, 20.03196179,
#        20.91486987, 20.03273703,  9.73505001, 17.17145455, 15.59615209,
#        21.83192584, 21.03377818, 22.48051568,  9.68066116, 17.9363401 ,
#        15.31952912, 19.22308084,  8.70696098, 10.4417962 , 10.05748759,
#        16.97899832, 24.77640741,  6.15903384, 23.65391108, 16.90746226,
#         7.7051198 , 21.08018419, 16.93635063, 19.07766459, 10.04486777,
#        12.13930744,  9.39305728, 13.7579924 , 12.2993106 , 15.50031314,
#        19.31754061, 21.07415849, 16.53252132, 12.13198994,  6.80668593,
#        19.76528434,  9.94086996, 21.49207935, 23.27847508,  5.25351206])

# %%
print(model.predict([[34,10,34]]))
# Out:
# [7.42257507]
# c:\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("Slope is",model.coef_)
# Out:
# Slope is [0.05428813 0.10694068 0.00092982]

# %%
print("Constant is",model.intercept_)
# Out:
# Constant is 4.4757577499255365

# %%
df1=pd.DataFrame({'Actual_Value':y_test,'Predicted_Value':y_pred,'Difference':y_test-y_pred})
df1
# Out:
#      Actual_Value  Predicted_Value  Difference
# 50           16.4        15.686215    0.713785
# 180          15.5        13.263043    2.236957
# 155           3.2         5.944151   -2.744151
# 198          25.5        24.424935    1.075065
# 185          22.6        20.446074    2.153926
# 132           5.7         7.842517   -2.142517
# 190          10.8        11.020794   -0.220794
# 160          16.4        15.804632    0.595368
# 182           8.7         8.163928    0.536072
# 86           12.0        11.573688    0.426312
# 107          12.0         9.437059    2.562941
# 170           8.4         8.447785   -0.047785
# 15           22.4        20.233917    2.166083
# 125          10.6        10.495665    0.104335
# 77           14.2        14.078491    0.121509
# 128          24.7        21.678502    3.021498
# 113          20.9        18.067477    2.832523
# 162          19.9        16.663072    3.236928
# 123          15.2        14.870304    0.329696
# 142          20.1        20.031962    0.068038
# 39           21.5        20.914870    0.585130
# 133          19.6        20.032737   -0.432737
# 191          11.9         9.735050    2.164950
# 3            16.5        17.171455   -0.671455
# 89           16.7        15.596152    1.103848
# 54           20.2        21.831926   -1.631926
# 33           17.4        21.033778   -3.633778
# 137          20.8        22.480516   -1.680516
# 149          10.1         9.680661    0.419339
# 187          17.3        17.936340   -0.636340
# 118          15.9        15.319529    0.580471
# 131          17.7        19.223081   -1.523081
# 10           12.6         8.706961    3.893039
# 18           11.3        10.441796    0.858204
# 29           10.5        10.057488    0.442512
# 105          15.0        16.978998   -1.978998
# 175          27.0        24.776407    2.223593
# 76            6.9         6.159034    0.740966
# 36           25.4        23.653911    1.746089
# 122          16.6        16.907462   -0.307462
# 172           7.6         7.705120   -0.105120
# 104          20.7        21.080184   -0.380184
# 154          20.6        16.936351    3.663649
# 59           18.4        19.077665   -0.677665
# 136           9.5        10.044868   -0.544868
# 73           11.0        12.139307   -1.139307
# 49            9.7         9.393057    0.306943
# 114          14.6        13.757992    0.842008
# 90           14.0        12.299311    1.700689
# 4            17.9        15.500313    2.399687
# 27           20.9        19.317541    1.582459
# 0            22.1        21.074158    1.025842
# 103          19.7        16.532521    3.167479
# 135          11.6        12.131990   -0.531990
# 189           6.7         6.806686   -0.106686
# 178          16.8        19.765284   -2.965284
# 32           13.2         9.940870    3.259130
# 188          20.9        21.492079   -0.592079
# 61           24.2        23.278475    0.921525
# 108           5.3         5.253512    0.046488

# %%
from sklearn.metrics import mean_absolute_error
MAE=mean_absolute_error(y_test,y_pred)
MAE
# Out:
# 1.342496639974725

# %%
from sklearn.metrics import mean_absolute_percentage_error
MAPE=mean_absolute_percentage_error(y_test,y_pred)
MAPE
# Out:
# 0.09723051550037029

# %%
from sklearn.metrics import mean_squared_error
MSE=mean_squared_error(y_test,y_pred)
MSE
# Out:
# 3.006283066869438

# %%
from sklearn.metrics import root_mean_squared_error
RMSE=root_mean_squared_error(y_test,y_pred)
RMSE
# Out:
# 1.7338636240689282

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
score
# Out:
# 0.9053489888853082
