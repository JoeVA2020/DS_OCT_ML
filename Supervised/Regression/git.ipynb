# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('https://raw.githubusercontent.com/arib168/data/main/50_Startups.csv')
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.dtypes
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %%
df.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
plt.scatter(df['R&D Spend'],df['Profit'], color='r')
plt.xlabel('R&D')
plt.ylabel('Profit')
plt.title('Expence profit')
# Out:
# Text(0.5, 1.0, 'Expence profit')

# %%
plt.scatter(df['Administration'],df['Profit'], color='r')
plt.xlabel('Administration')
plt.ylabel('Profit')
plt.title('Expence profit')
# Out:
# Text(0.5, 1.0, 'Expence profit')

# %%
plt.scatter(df['Marketing Spend'],df['Profit'], color='r')
plt.xlabel('Marketing')
plt.ylabel('Profit')
plt.title('Expence profit')
# Out:
# Text(0.5, 1.0, 'Expence profit')

# %%
plt.bar(df['State'],df['Profit'], color='r')
plt.xlabel('State')
plt.ylabel('Profit')
plt.title('Expence profit')
# Out:
# Text(0.5, 1.0, 'Expence profit')

# %%
y=df['Profit']
sns.regplot(x=df['R&D Spend'],y=y,color='r')
# Out:
# <Axes: xlabel='R&D Spend', ylabel='Profit'>

# %%
sns.regplot(x=df['Administration'],y=y,color='g')
# Out:
# <Axes: xlabel='Administration', ylabel='Profit'>

# %%
sns.regplot(x=df['Marketing Spend'],y=y,color='b')
# Out:
# <Axes: xlabel='Marketing Spend', ylabel='Profit'>

# %%
# sns.regplot(x=df['State'],y=y,color='c')

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.compose import make_column_transformer #to convert into difference column
from sklearn.preprocessing import OneHotEncoder
col_trans=make_column_transformer((OneHotEncoder(handle_unknown='ignore'),['State']),remainder='passthrough')
x=col_trans.fit_transform(x)
x
# Out:
# array([[0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.6534920e+05,
#         1.3689780e+05, 4.7178410e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.6259770e+05,
#         1.5137759e+05, 4.4389853e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.5344151e+05,
#         1.0114555e+05, 4.0793454e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.4437241e+05,
#         1.1867185e+05, 3.8319962e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.4210734e+05,
#         9.1391770e+04, 3.6616842e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.3187690e+05,
#         9.9814710e+04, 3.6286136e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.3461546e+05,
#         1.4719887e+05, 1.2771682e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.3029813e+05,
#         1.4553006e+05, 3.2387668e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.2054252e+05,
#         1.4871895e+05, 3.1161329e+05],
# ...

# %%
x.shape
# Out:
# (50, 6)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([150673.40681163, 172114.16710468,  64021.20610964, 162140.56365599,
#         57329.77708117,  88923.66815022, 153689.87460593, 130630.02291319,
#        100631.38554613, 114817.02201817])

# %%
df1=pd.DataFrame({'Actual_value':y_test,'Predicted_value':y_pred,'difference':y_test-y_pred})
df1
# Out:
#     Actual_value  Predicted_value    difference
# 8      152211.77    150673.406812   1538.363188
# 3      182901.99    172114.167105  10787.822895
# 38      81229.06     64021.206110  17207.853890
# 6      156122.51    162140.563656  -6018.053656
# 43      69758.98     57329.777081  12429.202919
# 34      96712.80     88923.668150   7789.131850
# 14     132602.65    153689.874606 -21087.224606
# 18     124266.90    130630.022913  -6363.122913
# 32      97427.84    100631.385546  -3203.545546
# 21     111313.02    114817.022018  -3504.002018

# %%
x=list(df.columns[0:-2])
print("slope is",list(zip(x,model.coef_)))
# Out:
# slope is [('R&D Spend', np.float64(262.9448404776935)), ('Administration', np.float64(2102.148339357217)), ('Marketing Spend', np.float64(-2365.0931798211877))]

# %%
print("constant is",model.intercept_)
# Out:
# constant is 46410.12153139158

# %%
from sklearn.metrics import mean_absolute_error
MAE=mean_absolute_error(y_test,y_pred)
MAE
# Out:
# 8992.83234820585

# %%
from sklearn.metrics import mean_absolute_percentage_error
MAPE=mean_absolute_percentage_error(y_test,y_pred)
MAPE
# Out:
# 0.08527820272185192

# %%
from sklearn.metrics import mean_squared_error
MSE=mean_squared_error(y_test,y_pred)
MSE
# Out:
# 117392765.86078498

# %%
from sklearn.metrics import root_mean_squared_error
RMSE=root_mean_squared_error(y_test,y_pred)
RMSE
# Out:
# 10834.794223278308

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
score
# Out:
# 0.8990488025554708
