# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('calories_data.csv')
df
# Out:
#         User_ID  Gender   Age  Height  Weight  Duration  Heart_Rate  \
# 0      14733363    male  68.0   190.0     NaN      29.0       105.0
# 1      14861698  female  20.0   166.0    60.0      14.0        94.0
# 2      11179863    male  69.0   179.0    79.0       5.0        88.0
# 3      16180408  female  34.0   179.0    71.0      13.0       100.0
# 4      17771927  female  27.0   154.0    58.0      10.0        81.0
# ...         ...     ...   ...     ...     ...       ...         ...
# 14995  15644082  female  20.0   193.0    86.0      11.0        92.0
# 14996  17212577  female  27.0   165.0    65.0       6.0        85.0
# 14997  17271188  female  43.0   159.0    58.0      16.0        90.0
# 14998  18643037    male  78.0   193.0    97.0       2.0        84.0
# 14999  11751526    male  63.0   173.0    79.0      18.0        92.0
#
#        Body_Temp  Calories
# 0           40.8     231.0
# 1           40.3      66.0
# 2           38.7      26.0
# 3           40.5      71.0
# ...

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.tail()
# Out:
#         User_ID  Gender   Age  Height  Weight  Duration  Heart_Rate  \
# 14995  15644082  female  20.0   193.0    86.0      11.0        92.0
# 14996  17212577  female  27.0   165.0    65.0       6.0        85.0
# 14997  17271188  female  43.0   159.0    58.0      16.0        90.0
# 14998  18643037    male  78.0   193.0    97.0       2.0        84.0
# 14999  11751526    male  63.0   173.0    79.0      18.0        92.0
#
#        Body_Temp  Calories
# 14995       40.4      45.0
# 14996       39.2      23.0
# 14997       40.1      75.0
# 14998       38.3      11.0
# 14999       40.5      98.0

# %%
df.columns
# Out:
# Index(['User_ID', 'Gender', 'Age', 'Height', 'Weight', 'Duration',
#        'Heart_Rate', 'Body_Temp', 'Calories'],
#       dtype='object')

# %%
df.dtypes
# Out:
# User_ID         int64
# Gender         object
# Age           float64
# Height        float64
# Weight        float64
# Duration      float64
# Heart_Rate    float64
# Body_Temp     float64
# Calories      float64
# dtype: object

# %%
df.isna().sum()
# Out:
# User_ID        0
# Gender         0
# Age           21
# Height         0
# Weight        14
# Duration       0
# Heart_Rate     0
# Body_Temp      0
# Calories       0
# dtype: int64

# %%
df.shape
# Out:
# (15000, 9)

# %%
df.describe()
# Out:
#             User_ID           Age        Height        Weight      Duration  \
# count  1.500000e+04  14979.000000  15000.000000  14986.000000  15000.000000
# mean   1.497736e+07     42.774952    174.465133     74.964500     15.530600
# std    2.872851e+06     16.974281     14.258114     15.037271      8.319203
# min    1.000116e+07     20.000000    123.000000     36.000000      1.000000
# 25%    1.247419e+07     28.000000    164.000000     63.000000      8.000000
# 50%    1.499728e+07     39.000000    175.000000     74.000000     16.000000
# 75%    1.744928e+07     56.000000    185.000000     87.000000     23.000000
# max    1.999965e+07     79.000000    222.000000    132.000000     30.000000
#
#          Heart_Rate     Body_Temp      Calories
# count  15000.000000  15000.000000  15000.000000
# mean      95.518533     40.025453     89.539533
# std        9.583328      0.779230     62.456978
# min       67.000000     37.100000      1.000000
# ...

# %%
df['Age'].unique()
# Out:
# array([68., 20., 69., 34., 27., 36., 33., 41., 60., 26., 21., nan, 32.,
#        53., 39., 46., 50., 67., 31., 48., 29., 42., 62., 38., 25., 24.,
#        22., 74., 70., 44., 61., 63., 54., 35., 28., 77., 64., 45., 66.,
#        57., 49., 47., 40., 55., 23., 43., 52., 79., 51., 59., 30., 37.,
#        56., 78., 58., 73., 65., 71., 75., 72., 76.])

# %%
df['Weight'].unique()
# Out:
# array([ nan,  60.,  79.,  71.,  58.,  50.,  56.,  85.,  94.,  51.,  76.,
#         54.,  62.,  82.,  67.,  65.,  86.,  93.,  59.,  75.,  73.,  88.,
#         68.,  84.,  80.,  57.,  70.,  66.,  55.,  98.,  69., 101.,  89.,
#         64.,  63.,  77.,  61.,  83.,  92.,  72., 100.,  91.,  74.,  87.,
#        107.,  53.,  96.,  81.,  90.,  45.,  52.,  49.,  78.,  47.,  95.,
#        109., 104., 102., 103., 105., 112.,  97.,  99., 111.,  42., 115.,
#         38.,  46., 108., 106.,  48.,  40.,  44., 114.,  41., 110.,  43.,
#        118., 113., 124., 117., 122., 120., 116., 121., 132.,  39., 119.,
#         36., 128., 126., 123.])

# %%
df['Age']=df['Age'].fillna(df['Age'].median())
df['Weight']=df['Weight'].fillna(df['Weight'].mean())
df.isna().sum()
# Out:
# User_ID       0
# Gender        0
# Age           0
# Height        0
# Weight        0
# Duration      0
# Heart_Rate    0
# Body_Temp     0
# Calories      0
# dtype: int64

# %%
df.drop(['User_ID'],axis=1,inplace=True)
df.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'Duration', 'Heart_Rate',
#        'Body_Temp', 'Calories'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
df['Gender']=label.fit_transform(df['Gender'])
df
# male :1   female: 0
# Out:
#        Gender   Age  Height   Weight  Duration  Heart_Rate  Body_Temp  \
# 0           1  68.0   190.0  74.9645      29.0       105.0       40.8
# 1           0  20.0   166.0  60.0000      14.0        94.0       40.3
# 2           1  69.0   179.0  79.0000       5.0        88.0       38.7
# 3           0  34.0   179.0  71.0000      13.0       100.0       40.5
# 4           0  27.0   154.0  58.0000      10.0        81.0       39.8
# ...       ...   ...     ...      ...       ...         ...        ...
# 14995       0  20.0   193.0  86.0000      11.0        92.0       40.4
# 14996       0  27.0   165.0  65.0000       6.0        85.0       39.2
# 14997       0  43.0   159.0  58.0000      16.0        90.0       40.1
# 14998       1  78.0   193.0  97.0000       2.0        84.0       38.3
# 14999       1  63.0   173.0  79.0000      18.0        92.0       40.5
#
#        Calories
# 0         231.0
# 1          66.0
# 2          26.0
# 3          71.0
# 4          35.0
# ...         ...
# ...

# %%
sns.countplot(x='Gender',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
gender_counts=df['Gender'].value_counts()
gender_labels=['Male','Female']

plt.figure(figsize=(8,5))
plt.pie(gender_counts,labels=gender_labels,autopct='%1.1f%%')
plt.show()

# %%
sns.scatterplot(x='Height',y='Weight',data=df)
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
plt.Figure(figsize=(20,10))
sns.barplot(x='Duration',y='Calories',data=df,palette='viridis',hue='Duration')
plt.title('Avg clories burned vs duration')
plt.ylabel('Avg Calories')
plt.show()

# %%
sns.scatterplot(x='Duration',y='Body_Temp',data=df,hue='Duration')
plt.show()

# %%
df.dtypes
# Out:
# Gender          int64
# Age           float64
# Height        float64
# Weight        float64
# Duration      float64
# Heart_Rate    float64
# Body_Temp     float64
# Calories      float64
# dtype: object

# %%
nummeric_columns = df.select_dtypes(include=[np.number]).columns
plt.figure(figsize=(9,6))
sns.boxenplot(data=df[nummeric_columns])
plt.title('Box plot of All Features')
plt.show()

# %%
outlier_columns=['Height','Weight','Heart_Rate','Body_Temp','Calories']

def remove_outliers(df,columns):
    for col in columns:
        
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        
        df=df[(df[col]>= lower_bound) & (df[col]<= upper_bound )]
    return df
df_cleaned= remove_outliers(df,outlier_columns)

# %%
correlation_matrix= df_cleaned.corr()

sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt='.2f',linewidths=1)
plt.title('Heatmap')
plt.show()

# %%
df_selected=df_cleaned.drop(columns=['Height','Gender'],axis=1)
correlation_matrix= df_selected.corr()

sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt='.2f',linewidths=0.5)
plt.title('Heatmap')
plt.show()

# %%
x=df_selected.iloc[:,:-1]
y=df_selected.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 14.51151008,  83.78490194,  14.87677565, ..., 101.9044555 ,
#         32.79280608,  36.8488347 ], shape=(4384,))

# %%
difference=pd.DataFrame({'Actual_Value':y_test,'Predicted_Value':y_pred,'Difference':y_test-y_pred})
difference
# Out:
#        Actual_Value  Predicted_Value  Difference
# 6590           16.0        14.511510    1.488490
# 8458           77.0        83.784902   -6.784902
# 5719           22.0        14.876776    7.123224
# 14270          24.0        22.193499    1.806501
# 14303         133.0       143.558505  -10.558505
# ...             ...              ...         ...
# 1988           48.0        54.318879   -6.318879
# 10649         129.0       133.511726   -4.511726
# 7345          106.0       101.904455    4.095545
# 12953          30.0        32.792806   -2.792806
# 3748           46.0        36.848835    9.151165
#
# [4384 rows x 3 columns]

# %%
print("Slope is",model.coef_)
# Out:
# Slope is [  0.51959807   0.10177876   6.65219149   2.01250149 -17.42792044]

# %%
print('constant is',model.intercept_)
# Out:
# constant is 461.69357705277184

# %%
from sklearn.metrics import mean_absolute_percentage_error
MAPE=mean_absolute_percentage_error(y_test,y_pred)
MAPE
# Out:
# 0.23674679046596891

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
score
# Out:
# 0.966084425470491
