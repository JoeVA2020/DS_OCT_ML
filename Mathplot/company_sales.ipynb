# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('company_sales_data.csv')
df.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
#Q1
df1=df['total_profit']
df_m=df['month_number']
plt.plot(df_m,df1,marker='o')
plt.xlabel('Month Number')
plt.ylabel('Total Profit')
plt.title("Month-Profit Graph")
# Out:
# Text(0.5, 1.0, 'Month-Profit Graph')

# %%
#Q2
plt.plot(df_m,df1,marker='o',linestyle='dotted',color='r',linewidth=3)
lab=['Units sold']
plt.xlabel('Month Number')
plt.ylabel('Sold units number')
plt.title("Month-Profit Graph")
plt.xticks(df['month_number'])
plt.yticks([100000,200000,300000,400000,500000,600000])
plt.legend(loc='lower right',labels=lab)
plt.tight_layout()

# %%
#q3
for i in df.columns[1:-2]:
    plt.plot(df["month_number"],df[i],marker='s',mfc='g')
plt.xlabel('Month Number')
plt.ylabel('Units sold')
plt.xticks(df['month_number'])
plt.show()

# %%
#Q4
plt.scatter(df['month_number'],df['toothpaste'])
plt.xlabel('Month Number')
plt.ylabel('Units sold')
# Out:
# Text(0, 0.5, 'Units sold')

# %%
#Q5
plt.bar([a-0.4 for a in df['month_number']],df['facecream'],align='edge',width=.4)
plt.bar([a+0.4 for a in df['month_number']],df['facewash'],align='edge',width=-.4)
plt.grid()
plt.xticks(df['month_number'])
lab=['Facecream','Facewash']
plt.legend(labels=lab)
plt.xlabel("Month Number")
plt.ylabel("Units Sold")
plt.title("Face Cream vs Face Wash Sales")
plt.show()

# %%
#q6
plt.hist(df['total_profit'])
# Out:
# (array([2., 4., 1., 1., 1., 1., 0., 1., 0., 1.]),
#  array([183300., 206250., 229200., 252150., 275100., 298050., 321000.,
#         343950., 366900., 389850., 412800.]),
#  <BarContainer object of 10 artists>)

# %%
#Q7
plt.figure(figsize=(20,5))
x=df.drop(columns=['month_number','total_units','total_profit']).sum()
lab=['facecream','facewash','toothpaste','bathingsoap','shampoo','moisturizer']
plt.pie(x,labels=lab,autopct='%1.0f%%')
plt.legend(loc='center left',labels=lab)
plt.tight_layout()

# %%
#Q8
plt.subplot(2,1,1)
plt.plot(df['month_number'],df['bathingsoap'])
plt.subplot(2,1,2)
plt.plot(df['month_number'],df['facewash'])
